# %% [markdown]
# ## Generating train and test sets
#
# **Author:** Benjamin Aw
# **Date:** 13 Dec 2021
# **Context:** Extracted data needs to be clean and split up for training and testing purposes.
# **Objective:** To apply previously generated functions to clean up the data, generate augmented data and finally to split them for training and testing purposes

# %% [markdown]
# #### A) Setting up
#
# Importing the libraries and obtaining the file path for the datasets required

# %%
import os
os.chdir('..')

# %%
import pandas as pd
from ssoc_autocoder.processing import final_cleaning
from ssoc_autocoder.processing import process_text
from ssoc_autocoder.augmentation import data_augmentation
from tqdm.auto import tqdm
import math
from itertools import chain
from sklearn.model_selection import train_test_split
import copy

#path = "../Data/"
path = 'Data/'

tqdm.pandas()

# %% [markdown]
# #### B) Functions
#
# We have to create 3 functions:
#
# 1. To clean up the original data, `cleaning_data`
# 2. To create augmented data, `augmenting_data`
# 3. To create the train test split, `splitting_data`

# %%
def cleaning_up_dataset(path):
    
    # Reading in the data
    df = pd.read_csv(path + "Raw/Raw_Labelled.csv")
    
    # Filtering out the necessary columns used, keeping Ad_ID as primary identifier
    df = df[["MCF_Job_Ad_ID", "Predicted_SSOC_2020", "title", "description"]]
    
    # Applying cleaning function across the description column
    df["description"] = df["description"].apply(process_text)
    
    return df

# %%
def augmenting_data(df, prob, edit_phrase):
    
    # Applying cleaning function across the description column
    df["description_augmented"] = df["description"].progress_apply(data_augmentation, args = (prob, edit_phrase))
    
    # Renaming description column
    df = df.rename(columns={'description':'description_originial'})
    
    # Appending to the original dataset
    df = pd.concat([df, df['description_augmented'].apply(pd.Series)], axis=1)
    
    # Dropping used or repeated columns
    df = df.drop(columns="description_augmented")
    df = df.drop(columns="orginal_text")
    
    return df

# %%
def supplementing_data(df, data_detailed_def):
    
    # Getting the relevant columns
    data_detailed_def = data_detailed_def[["SSOC 2020", "SSOC 2020 Title", "Detailed Definitions"]]
    
    # Filtering entries with only 5D ssoc and entries that start with X
    data_detailed_def = data_detailed_def[data_detailed_def["SSOC 2020"].apply(lambda x: len(x) > 4)]
    data_detailed_def = data_detailed_def[data_detailed_def["SSOC 2020"].apply(lambda x: x[0] != 'X')]
    
    # Need to change the SSOC data type to string
    data_detailed_def['SSOC 2020'] = data_detailed_def['SSOC 2020'].astype('str')
    
    # Changing column names for merging purposes
    data_detailed_def = data_detailed_def.rename(columns={"SSOC 2020": "Predicted_SSOC_2020", 
                                                          "SSOC 2020 Title": "title", 
                                                          "Detailed Definitions": "description"}, 
                                                 errors="raise")
    
    # Creating an additional column of ID, default to None for now
    data_detailed_def["MCF_Job_Ad_ID"] = None
    
    # Concat the two datasets together
    output = df.append(data_detailed_def)
    
    output = output.sort_values(by=['Predicted_SSOC_2020', 'title'])
    
    output = output.reset_index(drop=True)
    
    return output

# %%
def generate_train_test(df, 
                        train_set_size, 
                        min_samples = 2,
                        augmented = False):
    
    # Enforce the correct data type
    df["Predicted_SSOC_2020"] = df["Predicted_SSOC_2020"].astype('str')
    
    # All SSOC descriptions are automatically put into the training set
    # Retain only the real job ads in df
    ssoc_desc = df[df['MCF_Job_Ad_ID'].isnull()]
    df = df[df['MCF_Job_Ad_ID'].notnull()]
    
    # Identifying which SSOCs have only one sample vs those with multiple samples
    counter = df.groupby('Predicted_SSOC_2020').count().to_dict(orient='dict')['title']
    counter_once = { key:value for (key,value) in counter.items() if value == 1}
    counter_multiple = { key:value for (key,value) in counter.items() if value > 1}
    
    # Subset out the SSOCs that have multiple samples in the dataset 
    df_multiple = df[df["Predicted_SSOC_2020"].apply(lambda x: x in counter_multiple.keys())]
    
    # Shuffle them by generating indicators for whether they are in the train or test set
    df_multiple_train, df_multiple_test = train_test_split(df_multiple, train_size = .8, random_state = 2021, stratify = df_multiple['Predicted_SSOC_2020'])
    
    # Subset out the SSOCs that only have one sample in the dataset
    df_once = df[df["Predicted_SSOC_2020"].apply(lambda x: x in counter_once.keys())]
    
    # Append once with train
    df_train = pd.concat([ssoc_desc, df_once, df_multiple_train])
    df_test = copy.deepcopy(df_multiple_test)
    
    # If we are running this on the augmented dataset
    if augmented:

        # Pivot longer df_train
        df_train = pd.melt(df_train, 
                           id_vars= ["MCF_Job_Ad_ID", 
                                     "Predicted_SSOC_2020", 
                                     "title"], 
                           value_vars=["description_originial", 
                                       "wrd_emb_out", 
                                       "bk_trans_out", 
                                       "synonym_out", 
                                       "context_emb_out", 
                                       "sent_out", 
                                       "summ_out"],
                           var_name='Augment', 
                           value_name='job_description')

        # Pivot longer for df_test, we are only interested in testing on the orginal dataset
        df_test = pd.melt(df_multiple_test, 
                           id_vars= ["MCF_Job_Ad_ID", 
                                     "Predicted_SSOC_2020", 
                                     "title"], 
                           value_vars=["description_originial", 
                                       "wrd_emb_out", 
                                       "bk_trans_out", 
                                       "synonym_out", 
                                       "context_emb_out", 
                                       "sent_out", 
                                       "summ_out"],
                           var_name='Augment', 
                           value_name='job_description')
    
        df_test = df_test[df_test["Augment"] == "description_originial"]
    
    return df_train, df_test

# %% [markdown]
# #### C) Running functions

# %% [markdown]
# Reading in the raw csv file and subsequently cleaning up the dataset, while extacting only the necessary columns. The input of the function only requires the path of the csv file for `Raw_Labelled.csv`

# %%
df = cleaning_up_dataset(path)

df.to_csv(path + "Processed/Processed_Labelled.csv", index = False)
# Out:
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# Text length below 50. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# List object detected
# None detected, returning all
# List object detected
# Paragraphs detected
# List object detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# Paragraphs detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# None detected, returning all
# Paragraphs detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# Paragraphs detected
# List object detected
# Paragraph list detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# Paragraphs detected
# Text length below 100. Return cleaned original text.
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# Text length below 100. Return cleaned original text.
# None detected, returning all
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# List object detected
# Paragraphs detected
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# Paragraph list detected
# Paragraphs detected
# List object detected
# Paragraph list detected
# List object detected
# Paragraph list detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# Paragraph list detected
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# None detected, returning all
# List object detected
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# None detected, returning all
# None detected, returning all
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# None detected, returning all
# Text length below 100. Return cleaned original text.
# List object detected
# Paragraph list detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# List object detected
# None detected, returning all
# Paragraph list detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# Text length below 50. Return cleaned original text.
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# Paragraph list detected
# None detected, returning all
# List object detected
# Paragraph list detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# None detected, returning all
# List object detected
# Paragraph list detected
# None detected, returning all
# List object detected
# None detected, returning all
# List object detected
# List object detected
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# None detected, returning all
# Paragraph list detected
# List object detected
# Paragraph list detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# Paragraph list detected
# Paragraphs detected
# Paragraph list detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# Paragraphs detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# None detected, returning all
# Paragraph list detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# None detected, returning all
# List object detected
# Paragraph list detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# Paragraph list detected
# Text length below 100. Return cleaned original text.
# None detected, returning all
# Paragraph list detected
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# None detected, returning all
# Paragraph list detected
# Paragraph list detected
# List object detected
# List object detected
# Paragraphs detected
# Paragraph list detected
# List object detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# Text length below 100. Return cleaned original text.
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# None detected, returning all
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# Paragraphs detected
# List object detected
# None detected, returning all
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# Text length below 50. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# Paragraph list detected
# List object detected
# Paragraph list detected
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# List object detected
# Paragraph list detected
# Text length below 50. Return cleaned original text.
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# None detected, returning all
# Paragraphs detected
# None detected, returning all
# None detected, returning all
# List object detected
# None detected, returning all
# None detected, returning all
# None detected, returning all
# Text length below 100. Return cleaned original text.
# None detected, returning all
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# None detected, returning all
# Paragraph list detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# Paragraph list detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# Paragraphs detected
# Paragraph list detected
# List object detected
# Paragraphs detected
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# None detected, returning all
# List object detected
# Paragraph list detected
# Paragraph list detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# Paragraphs detected
# None detected, returning all
# List object detected
# List object detected
# Paragraphs detected
# Paragraph list detected
# List object detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# Text length below 100. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# None detected, returning all
# List object detected
# None detected, returning all
# List object detected
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# None detected, returning all
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# Paragraph list detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# Paragraphs detected
# List object detected
# List object detected
# Paragraph list detected
# None detected, returning all
# List object detected
# List object detected
# List object detected
# List object detected
# None detected, returning all
# List object detected
# List object detected
# Paragraph list detected
# None detected, returning all
# None detected, returning all
# Paragraph list detected
# Paragraph list detected
# Text length below 50. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# List object detected
# Paragraph list detected
# Text length below 100. Return cleaned original text.
# List object detected
# None detected, returning all
# List object detected
# Text length below 100. Return cleaned original text.
# None detected, returning all
# Paragraph list detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# Paragraphs detected
# Text length below 100. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# Paragraph list detected
# Paragraphs detected
# Paragraph list detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# Text length below 100. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# Paragraph list detected
# List object detected
# Text length below 100. Return cleaned original text.
# None detected, returning all
# Paragraphs detected
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# List object detected
# Paragraph list detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# Paragraph list detected
# None detected, returning all
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# Text length below 100. Return cleaned original text.
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# List object detected
# Text length below 100. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# Paragraph list detected
# List object detected
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# None detected, returning all
# Paragraph list detected
# List object detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# Text length below 50. Return cleaned original text.
# None detected, returning all
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# Paragraph list detected
# None detected, returning all
# List object detected
# List object detected
# Paragraphs detected
# Paragraph list detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# List object detected
# None detected, returning all
# None detected, returning all
# List object detected
# List object detected
# None detected, returning all
# List object detected
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# Text length below 50. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# List object detected
# Paragraphs detected
# List object detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# List object detected
# List object detected
# Paragraphs detected
# Paragraph list detected
# Text length below 50. Return cleaned original text.
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# None detected, returning all
# List object detected
# Paragraph list detected
# List object detected
# Paragraph list detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# Paragraph list detected
# Text length below 50. Return cleaned original text.
# List object detected
# Paragraph list detected
# None detected, returning all
# List object detected
# List object detected
# List object detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# List object detected
# None detected, returning all
# Paragraph list detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# Paragraphs detected
# Paragraph list detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# None detected, returning all
# Paragraph list detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# List object detected
# None detected, returning all
# List object detected
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# Paragraphs detected
# Paragraph list detected
# Paragraph list detected
# Paragraphs detected
# List object detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# Paragraphs detected
# List object detected
# List object detected
# Paragraphs detected
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# None detected, returning all
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# Text length below 100. Return cleaned original text.
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# Paragraph list detected
# Paragraphs detected
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# None detected, returning all
# Paragraphs detected
# Paragraph list detected
# List object detected
# None detected, returning all
# Paragraph list detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# Paragraphs detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# List object detected
# None detected, returning all
# List object detected
# List object detected
# Paragraphs detected
# List object detected
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# List object detected
# List object detected
# None detected, returning all
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# Paragraphs detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# Text length below 50. Return cleaned original text.
# Paragraphs detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# None detected, returning all
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# Paragraphs detected
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# Paragraphs detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# Paragraphs detected
# List object detected
# Paragraph list detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# None detected, returning all
# Paragraph list detected
# List object detected
# Paragraph list detected
# List object detected
# Paragraphs detected
# Paragraph list detected
# List object detected
# List object detected
# None detected, returning all
# Paragraph list detected
# List object detected
# Paragraph list detected
# Paragraphs detected
# Paragraph list detected
# Paragraph list detected
# Text length below 100. Return cleaned original text.
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# Paragraphs detected
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# Paragraph list detected
# Paragraphs detected
# List object detected
# Paragraph list detected
# List object detected
# None detected, returning all
# None detected, returning all
# Text length below 100. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# List object detected
# Paragraph list detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# None detected, returning all
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# Paragraph list detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# Paragraphs detected
# Paragraphs detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# None detected, returning all
# Text length below 100. Return cleaned original text.
# None detected, returning all
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# Paragraphs detected
# Paragraph list detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# None detected, returning all
# List object detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# Text length below 100. Return cleaned original text.
# List object detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# Paragraph list detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# Text length below 50. Return cleaned original text.
# Paragraphs detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# Paragraphs detected
# Paragraph list detected
# Paragraph list detected
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# None detected, returning all
# Paragraph list detected
# Text length below 50. Return cleaned original text.
# List object detected
# None detected, returning all
# List object detected
# None detected, returning all
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# None detected, returning all
# List object detected
# Paragraphs detected
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# None detected, returning all
# Paragraph list detected
# Paragraphs detected
# None detected, returning all
# List object detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# List object detected
# List object detected
# Paragraphs detected
# Paragraph list detected
# List object detected
# Paragraph list detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# None detected, returning all
# Paragraph list detected
# List object detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# Paragraphs detected
# Paragraph list detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# List object detected
# None detected, returning all
# Paragraph list detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# List object detected
# Text length below 50. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# List object detected
# Paragraph list detected
# List object detected
# Paragraphs detected
# List object detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# Paragraph list detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# Paragraph list detected
# Paragraph list detected
# None detected, returning all
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# List object detected
# List object detected
# Paragraphs detected
# Paragraph list detected
# List object detected
# Text length below 50. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# Paragraphs detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# Text length below 50. Return cleaned original text.
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# Paragraphs detected
# List object detected
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# Paragraph list detected
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# List object detected
# Paragraph list detected
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# List object detected
# Text length below 50. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# Paragraphs detected
# Paragraphs detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# Paragraphs detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# List object detected
# Text length below 50. Return cleaned original text.
# None detected, returning all
# None detected, returning all
# Paragraph list detected
# Paragraph list detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# None detected, returning all
# List object detected
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# Paragraph list detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# Text length below 100. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# List object detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# List object detected
# None detected, returning all
# List object detected
# Paragraph list detected
# List object detected
# Paragraph list detected
# List object detected
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# List object detected
# Text length below 50. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# None detected, returning all
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# None detected, returning all
# List object detected
# List object detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# Text length below 50. Return cleaned original text.
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# Paragraph list detected
# List object detected
# None detected, returning all
# List object detected
# List object detected
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# Paragraphs detected
# List object detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# None detected, returning all
# Paragraph list detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# Paragraph list detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# None detected, returning all
# Paragraph list detected
# List object detected
# List object detected
# Paragraph list detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# List object detected
# List object detected
# Paragraph list detected
# Paragraphs detected
# List object detected
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# Paragraphs detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# Paragraph list detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# List object detected
# None detected, returning all
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# None detected, returning all
# Paragraphs detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# Paragraphs detected
# Paragraph list detected
# Paragraphs detected
# List object detected
# List object detected
# Paragraphs detected
# List object detected
# None detected, returning all
# List object detected
# Paragraphs detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# Text length below 100. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# Text length below 100. Return cleaned original text.
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# Paragraphs detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# Paragraph list detected
# Paragraphs detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Paragraphs detected
# List object detected
# List object detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# Text length below 50. Return cleaned original text.
# None detected, returning all
# Paragraphs detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# None detected, returning all
# Paragraph list detected
# Text length below 50. Return cleaned original text.
# None detected, returning all
# List object detected
# Paragraph list detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Paragraphs detected
# List object detected
# List object detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# Text length below 50. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# List object detected
# Paragraphs detected
# List object detected
# None detected, returning all
# Paragraph list detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# List object detected
# None detected, returning all
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# Paragraph list detected
# Paragraph list detected
# Paragraph list detected
# Text length below 100. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# List object detected
# Paragraph list detected
# Paragraph list detected
# Paragraph list detected
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# Paragraphs detected
# Text length below 100. Return cleaned original text.
# Paragraphs detected
# Paragraph list detected
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# Paragraph list detected
# List object detected
# List object detected
# Paragraphs detected
# List object detected
# List object detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# Text length below 100. Return cleaned original text.
# List object detected
# Paragraph list detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# Text length below 100. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# Paragraphs detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# List object detected
# Paragraph list detected
# Paragraphs detected
# List object detected
# List object detected
# Paragraph list detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# Paragraph list detected
# Text length below 100. Return cleaned original text.
# Paragraphs detected
# List object detected
# None detected, returning all
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# List object detected
# Paragraphs detected
# List object detected
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# List object detected
# List object detected
# Paragraphs detected
# Paragraph list detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# Paragraph list detected
# List object detected
# Text length below 100. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# Paragraphs detected
# List object detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# Paragraph list detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# Text length below 100. Return cleaned original text.
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# Paragraph list detected
# List object detected
# None detected, returning all
# Paragraphs detected
# Paragraphs detected
# Paragraph list detected
# List object detected
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# Paragraph list detected
# Text length below 50. Return cleaned original text.
# List object detected
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# List object detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# None detected, returning all
# None detected, returning all
# List object detected
# Paragraph list detected
# Text length below 100. Return cleaned original text.
# List object detected
# ...
# None detected, returning all
# Paragraphs detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# None detected, returning all
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# None detected, returning all
# None detected, returning all
# List object detected
# None detected, returning all
# Paragraph list detected
# List object detected
# Text length below 50. Return cleaned original text.
# None detected, returning all
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# Paragraphs detected
# None detected, returning all
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# Paragraph list detected
# Text length below 50. Return cleaned original text.
# List object detected
# Text length below 100. Return cleaned original text.
# None detected, returning all
# Paragraph list detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# None detected, returning all
# List object detected
# Paragraph list detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# Text length below 100. Return cleaned original text.
# List object detected
# Paragraphs detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# Paragraph list detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# Paragraph list detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# Text length below 100. Return cleaned original text.
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# None detected, returning all
# None detected, returning all
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# None detected, returning all
# List object detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# None detected, returning all
# Text length below 100. Return cleaned original text.
# List object detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# None detected, returning all
# Text length below 100. Return cleaned original text.
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# List object detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# None detected, returning all
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# Text length below 50. Return cleaned original text.
# List object detected
# Text length below 50. Return cleaned original text.
# None detected, returning all
# List object detected
# Paragraphs detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# Text length below 50. Return cleaned original text.
# None detected, returning all
# Text length below 100. Return cleaned original text.
# List object detected
# None detected, returning all
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# Paragraph list detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# List object detected
# Paragraphs detected
# Paragraph list detected
# List object detected
# Paragraph list detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# Paragraph list detected
# List object detected
# Paragraph list detected
# List object detected
# Text length below 50. Return cleaned original text.
# None detected, returning all
# List object detected
# List object detected
# Paragraph list detected
# None detected, returning all
# None detected, returning all
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# None detected, returning all
# Text length below 100. Return cleaned original text.
# List object detected
# List object detected
# List object detected
# List object detected
# None detected, returning all
# None detected, returning all
# Text length below 100. Return cleaned original text.
# Paragraph list detected
# Text length below 50. Return cleaned original text.
# List object detected
# None detected, returning all
# List object detected
# Text length below 50. Return cleaned original text.
# Paragraphs detected
# List object detected
# List object detected
# List object detected
# None detected, returning all
# None detected, returning all
# None detected, returning all
# Paragraph list detected
# None detected, returning all
# Paragraphs detected
# Paragraphs detected
# Text length below 50. Return cleaned original text.
# Paragraph list detected
# List object detected
# Paragraph list detected
# Paragraph list detected
# List object detected
# List object detected
# List object detected
# List object detected
# Paragraphs detected
# Paragraph list detected
# List object detected
# Paragraph list detected
# Paragraphs detected
# List object detected
# Paragraphs detected
# Paragraphs detected
# None detected, returning all
# None detected, returning all
# List object detected
# List object detected
# None detected, returning all
# Text length below 100. Return cleaned original text.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24216/3002893419.py in <module>
# ----> 1 df = cleaning_up_dataset(path)
#       2
#       3 df.to_csv(path + "Processed/Processed_Labelled.csv", index = False)
#
# ~\AppData\Local\Temp/ipykernel_24216/1687844476.py in cleaning_up_dataset(path)
#       8
#       9     # Applying cleaning function across the description column
# ---> 10     df["description"] = df["description"].apply(process_text)
#      11
#      12     return df
#
# c:\users\shaun\pycharmprojects\ssoc-autocoder\venv\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4354         dtype: float64
#    4355         """
# -> 4356         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4357
#    4358     def _reduce(
#
# c:\users\shaun\pycharmprojects\ssoc-autocoder\venv\lib\site-packages\pandas\core\apply.py in apply(self)
#    1034             return self.apply_str()
#    1035
# -> 1036         return self.apply_standard()
#    1037
#    1038     def agg(self):
#
# c:\users\shaun\pycharmprojects\ssoc-autocoder\venv\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1090                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1091                 # "Callable[[Any], Any]"
# -> 1092                 mapped = lib.map_infer(
#    1093                     values,
#    1094                     f,  # type: ignore[arg-type]
#
# c:\users\shaun\pycharmprojects\ssoc-autocoder\venv\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\PycharmProjects\ssoc-autocoder\ssoc_autocoder\processing.py in process_text(raw_text)
#     482     li_results = process_li_tag(text, nlp)
#     483     p_list_results = process_p_list(text, nlp)
# --> 484     p_results = process_p_tag(text, nlp)
#     485
#     486     # After subsetting, we relax the min length criteria
#
# ~\PycharmProjects\ssoc-autocoder\ssoc_autocoder\processing.py in process_p_tag(text, nlp)
#     319
#     320         if len(para_element_cleaned) > 0:
# --> 321             if check_if_first_word_is_verb(para_element_cleaned, nlp):
#     322                 output.append(para_element)
#     323
#
# ~\PycharmProjects\ssoc-autocoder\ssoc_autocoder\processing.py in check_if_first_word_is_verb(string, nlp)
#      75
#      76     # Check if the first word is a verb
# ---> 77     return nlp(string)[0].pos_ == 'VERB'
#      78
#      79
#
# c:\users\shaun\pycharmprojects\ssoc-autocoder\venv\lib\site-packages\spacy\language.py in __call__(self, text, disable, component_cfg)
#     998                 error_handler = proc.get_error_handler()
#     999             try:
# -> 1000                 doc = proc(doc, **component_cfg.get(name, {}))
#    1001             except KeyError as e:
#    1002                 # This typically happens if a component is not initialized
#
# c:\users\shaun\pycharmprojects\ssoc-autocoder\venv\lib\site-packages\spacy\pipeline\trainable_pipe.pyx in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
#
# c:\users\shaun\pycharmprojects\ssoc-autocoder\venv\lib\site-packages\spacy\pipeline\tok2vec.py in predict(self, docs)
#     119         DOCS: https://spacy.io/api/tok2vec#predict
#     120         """
# --> 121         tokvecs = self.model.predict(docs)
#     122         batch_id = Tok2VecListener.get_batch_id(docs)
#     123         for listener in self.listeners:
#
# c:\users\shaun\pycharmprojects\ssoc-autocoder\venv\lib\site-packages\thinc\model.py in predict(self, X)
#     313         only the output, instead of the `(output, callback)` tuple.
#     314         """
# --> 315         return self._func(self, X, is_train=False)[0]
#     316
#     317     def finish_update(self, optimizer: Optimizer) -> None:
#
# c:\users\shaun\pycharmprojects\ssoc-autocoder\venv\lib\site-packages\thinc\layers\chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# c:\users\shaun\pycharmprojects\ssoc-autocoder\venv\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# c:\users\shaun\pycharmprojects\ssoc-autocoder\venv\lib\site-packages\thinc\layers\chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# c:\users\shaun\pycharmprojects\ssoc-autocoder\venv\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# c:\users\shaun\pycharmprojects\ssoc-autocoder\venv\lib\site-packages\thinc\layers\with_array.py in forward(model, Xseq, is_train)
#      28 def forward(model: Model[SeqT, SeqT], Xseq: SeqT, is_train: bool):
#      29     if isinstance(Xseq, Ragged):
# ---> 30         return _ragged_forward(
#      31             cast(Model[Ragged, Ragged], model), cast(Ragged, Xseq), is_train
#      32         )
#
# c:\users\shaun\pycharmprojects\ssoc-autocoder\venv\lib\site-packages\thinc\layers\with_array.py in _ragged_forward(model, Xr, is_train)
#      88 ) -> Tuple[Ragged, Callable]:
#      89     layer: Model[ArrayXd, ArrayXd] = model.layers[0]
# ---> 90     Y, get_dX = layer(Xr.dataXd, is_train)
#      91
#      92     def backprop(dYr: Ragged) -> Ragged:
#
# c:\users\shaun\pycharmprojects\ssoc-autocoder\venv\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# c:\users\shaun\pycharmprojects\ssoc-autocoder\venv\lib\site-packages\thinc\layers\chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# c:\users\shaun\pycharmprojects\ssoc-autocoder\venv\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# c:\users\shaun\pycharmprojects\ssoc-autocoder\venv\lib\site-packages\thinc\layers\chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# c:\users\shaun\pycharmprojects\ssoc-autocoder\venv\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# c:\users\shaun\pycharmprojects\ssoc-autocoder\venv\lib\site-packages\thinc\layers\maxout.py in forward(model, X, is_train)
#      47     W = model.get_param("W")
#      48     W = model.ops.reshape2f(W, nO * nP, nI)
# ---> 49     Y = model.ops.gemm(X, W, trans2=True)
#      50     Y += model.ops.reshape1f(b, nO * nP)
#      51     Z = model.ops.reshape3f(Y, Y.shape[0], nO, nP)
#
# KeyboardInterrupt:

# %% [markdown]
# Once the dataset is extracted, we need to supplement information of SSOCS that are not present in the current dataset. This is done by merging the dataset with `SSOC2020 Detailed Definitions.xlsx`

# %%
# Chunk to read in output from above cell, only do this if you have run the above function before

df = pd.read_csv(path + "Processed/Processed_Labelled.csv")

# %%
data_detailed_def = pd.read_excel(path + "Reference/SSOC2020 Detailed Definitions.xlsx", header = 4)

df = supplementing_data(df, data_detailed_def)

df.to_csv(path + "Reference/Intermediate_Dataset.csv", index = False)
# Out:
# c:\users\shaun\pycharmprojects\ssoc-autocoder\venv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %% [markdown]
# Because augmenting all 15k entries will take a while, we take a sample of the dataset to augment to test for now. We have to find a better way to run the augmentation, since it will take about 9-10 days to run locally on my own PC.

# %%
# df = df.sample(n = 200)

# %% [markdown]
# Augmenting the current dataset, where each row represents a job description, and the additional columns added represents the augmented data

# %%
# df = augmenting_data(df, 0.5, True)
# df.to_csv(path + "Processed/Processed_Augmented_Labelled_sample.csv", index = False)

# %% [markdown]
# Now we want to split the dataset into a train test set.
#
# If there is only one SSOC value present in the dataset, we leave that in as a training set.
#
# If there are more than one entry for a particular SSOC value, we split them up based on the second argument in the `train_test_split` function, and append the training section with the one above.

# %%
# Chunk to read in output from above cell, only do this if you have run the above function before
# df = pd.read_csv(path + "Processed/Processed_Augmented_Labelled_sample.csv")

# %%
train, test = generate_train_test(df, 0.8)

# %% [markdown]
# Check the number of SSOCs in both the train and test sets

# %%
for ssoc in test['Predicted_SSOC_2020'].unique():
    if ssoc not in train['Predicted_SSOC_2020'].values:
        print(ssoc)

# %%
print(train['Predicted_SSOC_2020'].nunique())
print(test['Predicted_SSOC_2020'].nunique())
# Out:
# 997
# 382

# %%
train.to_csv(path + "Train/Train.csv", index = False)
test.to_csv(path + "Train/Test.csv", index = False)

# %% [markdown]
# #### D)

# %%
extra_validation = pd.read_csv('Data/Reference/MCF_JobPostings_500_ValidatedbyMRSD.csv')

# %%
import hashlib
extra_validation['uuid'] = [hashlib.md5(job_id.encode()).hexdigest() for job_id in extra_validation['jobid']]

# %%
def cleaning_text_and_check(text):
    
    cleaned_text = final_cleaning(text)
    
    # add in additional check for proper sentences
    
    return cleaned_text

def output_combined_file(path):

    df_list = []
    for filename in os.listdir(path):

        print(f'Processing {filename}...\r', end = '')
        df = pd.read_csv(path + "/" + filename)
        df_list.append(df)
    
    print('')
    combined_df = pd.concat(df_list, ignore_index = True)
    print(f'Shape of combined dataframe: {combined_df.shape}')

    return combined_df

combined_df = output_combined_file('Data/Raw/mcf_api_responses_csv')
# Out:
# Processing raw_2021-05.csv...
# Shape of combined dataframe: (882214, 19)

# %%
extra_validation_full = extra_validation.merge(combined_df, how = 'left', on = 'uuid')

# %%
output = extra_validation_full[['jobid', 'title', 'description', 'SSOC 2020']] 
output.columns = ['MCF_Job_Ad_ID', 'title', 'description', 'Predicted_SSOC_2020']

# %%
output.to_csv('Data/Train/MRSD_Validation.csv', index = False)
