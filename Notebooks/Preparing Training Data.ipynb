# %% [markdown]
# ## Pulling

# %%
import os
os.chdir('..')

# %%
import pandas as pd
import requests
import hashlib 
import time

# %%
df_preds = pd.read_csv('Data/Processed/MCF_Training_Set.csv').drop_duplicates()

# %%
df_preds['uuid'] = [hashlib.md5(job_id.encode()).hexdigest() for job_id in df_preds['MCF_Job_Ad_ID']]

# %%
len(df_preds)
# Out:
# 53888

# %%
base_url = 'https://api.mycareersfuture.gov.sg/v2/jobs'

output = []
for i, uuid in enumerate(df_preds['uuid']):
    if i < 33653:
        continue
    req = requests.get(base_url + "/" + uuid)
    if (i+1) % 10 == 0:
        print(f"Completed {i+1}...\r", end = '')
        time.sleep(.1)
    if req.status_code == 200:
        output.append(req.json())
    else:
        print('Backing off for 2 seconds...')
        time.sleep(2)
        req = requests.get(base_url + "/" + uuid)
        output.append(req.json())
# Out:
# Backing off for 2 seconds...
# Backing off for 2 seconds...
# Backing off for 2 seconds...
# Backing off for 2 seconds...
# Backing off for 2 seconds...
# Completed 53880...

# %%
len(output)
# Out:
# 20235

# %%
import copy
saved = copy.deepcopy(output)

# %%
len(saved)
# Out:
# 33654

# %%
final = saved + output[1:]

# %%
final[0]
# Out:
# {'uuid': '539df02ed701baaa6d20b5e8fb82b9cc',
#  'sourceCode': 'Employer Portal',
#  'title': 'Sales director',
#  'description': '<h3>Responsibilities:</h3>\n<h3>· Lead the management team and being responsible for the APAC partnerships</h3>\n<h3>· Growing the revenue through orchestrating execution and strategic planning across different channels of clients</h3>\n<h3>· Ability to leverage across Business to Business clients and targeting the cross functionally – offering exemplary customer service support for the food safety clients across the region</h3>\n<h3>· Growth of the services and education portfolio through key customers</h3>\n<h3>Requirements:</h3>\n<h3>· Minimum 10 years in the food industry</h3>\n<h3>· Track record of success across business development and marketing across the region</h3>\n<h3>· Must have excellent communication skills as well as sensitivity towards all markets</h3>\n<h3>· Strong negotiations and ability to strategise and always see further opportunities across the region</h3>\n<h3>· Ability to travel domestically and internationally</h3>',
#  'minimumYearsExperience': 10,
#  'shiftPattern': None,
#  'schemes': [],
#  'otherRequirements': None,
#  'ssocCode': 1808,
#  'workingHours': None,
#  'numberOfVacancies': 1,
#  'psdUrl': None,
#  'categories': [{'id': 15, 'category': 'F&B'},
#   {'id': 16, 'category': 'General Management'},
#   {'id': 26, 'category': 'Marketing / Public Relations'},
#   {'id': 35, 'category': 'Sales / Retail'}],
#  'employmentTypes': [{'id': 3, 'employmentType': 'Contract'}],
#  'positionLevels': [{'id': 1, 'position': 'Senior Management'}],
#  'status': {'id': 9, 'jobStatus': 'Closed'},
#  'skills': [{'id': 59,
#    'skill': 'Account Management',
#    'uuid': '09f0c5159c5e34504e453eff3fc70324',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/09f0c5159c5e34504e453eff3fc70324'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/09f0c5159c5e34504e453eff3fc70324/jobs'}}},
#   {'id': 8678,
#    'skill': 'Strategic Planning',
#    'uuid': '1056ea32e61274889e2f1b9c48a5a515',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/1056ea32e61274889e2f1b9c48a5a515'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/1056ea32e61274889e2f1b9c48a5a515/jobs'}}},
#   {'id': 7819,
#    'skill': 'Sales',
#    'uuid': '11ff9f68afb6b8b5b8eda218d7c83a65',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/11ff9f68afb6b8b5b8eda218d7c83a65'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/11ff9f68afb6b8b5b8eda218d7c83a65/jobs'}}},
#   {'id': 5006,
#    'skill': 'Leadership',
#    'uuid': '1f0aef4f272d1541fc70d2e3b3fbccf7',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/1f0aef4f272d1541fc70d2e3b3fbccf7'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/1f0aef4f272d1541fc70d2e3b3fbccf7/jobs'}}},
#   {'id': 3520,
#    'skill': 'Food Safety',
#    'uuid': '337f066be0dbb0a5fc329b19aaf5f365',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/337f066be0dbb0a5fc329b19aaf5f365'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/337f066be0dbb0a5fc329b19aaf5f365/jobs'}}},
#   {'id': 7837,
#    'skill': 'Sales Management',
#    'uuid': '5570b1274928746e87170e404f4553a1',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/5570b1274928746e87170e404f4553a1'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/5570b1274928746e87170e404f4553a1/jobs'}}},
#   {'id': 100205,
#    'skill': 'Partnership',
#    'uuid': '5e4c2b30e54de67b17ff0f2456dbc71a',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/5e4c2b30e54de67b17ff0f2456dbc71a'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/5e4c2b30e54de67b17ff0f2456dbc71a/jobs'}}},
#   {'id': 3511,
#    'skill': 'Food Industry',
#    'uuid': '77429758d15f7e54cd0c35ebe29378a5',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/77429758d15f7e54cd0c35ebe29378a5'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/77429758d15f7e54cd0c35ebe29378a5/jobs'}}},
#   {'id': 101635,
#    'skill': 'Targeting',
#    'uuid': '78781cc1291aa54a9008720982b04563',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/78781cc1291aa54a9008720982b04563'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/78781cc1291aa54a9008720982b04563/jobs'}}},
#   {'id': 8692,
#    'skill': 'Strategy',
#    'uuid': '83de191c12c3c109006c4593128d8bb6',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/83de191c12c3c109006c4593128d8bb6'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/83de191c12c3c109006c4593128d8bb6/jobs'}}},
#   {'id': 108297,
#    'skill': 'business to business clients',
#    'uuid': '882274f0578605cb1c794381cf36eb8d',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/882274f0578605cb1c794381cf36eb8d'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/882274f0578605cb1c794381cf36eb8d/jobs'}}},
#   {'id': 6020,
#    'skill': 'New Business Development',
#    'uuid': 'b0663aff7f5d34d384fa0010772717c0',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/b0663aff7f5d34d384fa0010772717c0'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/b0663aff7f5d34d384fa0010772717c0/jobs'}}},
#   {'id': 983,
#    'skill': 'Business Development',
#    'uuid': 'db01e6ae90744aebba2ed0faefb8ceed',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/db01e6ae90744aebba2ed0faefb8ceed'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/db01e6ae90744aebba2ed0faefb8ceed/jobs'}}},
#   {'id': 100162,
#    'skill': 'customer service support',
#    'uuid': 'f0de07bbb529e60f3934fd8a8bf74acb',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/f0de07bbb529e60f3934fd8a8bf74acb'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/f0de07bbb529e60f3934fd8a8bf74acb/jobs'}}},
#   {'id': 5319,
#    'skill': 'Management',
#    'uuid': 'fe4dbcab9b910577e5035e97ac068dae',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/fe4dbcab9b910577e5035e97ac068dae'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/fe4dbcab9b910577e5035e97ac068dae/jobs'}}}],
#  'ssecEqa': '70',
#  'ssecFos': '0511',
#  'postedCompany': {'uen': '201803664H',
#   'description': None,
#   'name': 'ARGYLL SCOTT CONSULTING PTE. LTD.',
#   'ssicCode': '70201',
#   'registrationTypeId': 1,
#   'employeeCount': None,
#   'companyUrl': None,
#   'lastSyncDate': '2021-09-24T05:40:46.000Z',
#   'badges': [{'badgeType': 'Tripartite',
#     'badgeCode': '002',
#     'badgeName': 'Tripartite Standard on Flexible Work Arrangements',
#     'description': 'Implementing FWAs successfully through training and senior management support.',
#     'url': 'https://www.tafep.sg/flexible-work-arrangements',
#     'source': 'Tafep',
#     'startDate': '2021-09-30',
#     'expiryDate': '2022-09-30'},
#    {'badgeType': 'Tripartite',
#     'badgeCode': '004',
#     'badgeName': 'Tripartite Standard on Recruitment Practices',
#     'description': 'Adopting fair merit-based and inclusive hiring practices to better attract and retain talent.',
#     'url': 'https://www.tafep.sg/recruitment-practices',
#     'source': 'Tafep',
#     'startDate': '2021-09-30',
#     'expiryDate': '2022-09-30'},
#    {'badgeType': 'Tripartite',
#     'badgeCode': '007',
#     'badgeName': 'Tripartite Standard on Unpaid Leave for Unexpected Care Needs',
#     'description': 'Supporting employees’ caregiving needs with unpaid leave.',
#     'url': 'https://www.tafep.sg/unpaid-leave-unexpected-care-needs',
#     'source': 'Tafep',
#     'startDate': '2021-09-30',
#     'expiryDate': '2022-09-30'}],
#   '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/companies/201803664H'},
#    'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/companies/201803664H/jobs'},
#    'addresses': {'href': 'https://api.mycareersfuture.gov.sg/v2/companies/201803664H/addresses'},
#    'schemes': {'href': 'https://api.mycareersfuture.gov.sg/v2/companies/201803664H/schemes'}},
#   'logoFileName': None,
#   'logoUploadPath': None},
#  'hiringCompany': None,
#  'screeningQuestions': [],
#  'address': {'overseasCountry': None,
#   'foreignAddress1': None,
#   'foreignAddress2': None,
#   'block': '36 / #03-118',
#   'street': 'Robinson Road',
#   'floor': None,
#   'unit': None,
#   'building': 'We Work City House',
#   'postalCode': '068877',
#   'isOverseas': False,
#   'districts': [{'id': 1,
#     'location': 'D01 Cecil, Marina, People’s Park, Raffles Place',
#     'region': 'Central',
#     'sectors': ['01', '02', '03', '04', '05', '06'],
#     'regionId': 'Central'}],
#   'lat': 1.2812201995343,
#   'lng': 103.849798336253},
#  'metadata': {'jobPostId': 'MCF-2020-0004327',
#   'deletedAt': '2020-01-21T22:38:50.000Z',
#   'createdBy': '4bf28ef0-5bd5-43b9-bd52-0b622eac482f',
#   'createdAt': '2020-01-07T08:40:25.000Z',
#   'updatedAt': '2020-01-22T10:39:33.000Z',
#   'editCount': 0,
#   'repostCount': 0,
#   'totalNumberOfView': 53,
#   'newPostingDate': '2020-01-07',
#   'originalPostingDate': '2020-01-07',
#   'expiryDate': '2020-01-21',
#   'totalNumberJobApplication': 0,
#   'isPostedOnBehalf': False,
#   'isHideSalary': False,
#   'isHideCompanyAddress': False,
#   'isHideHiringEmployerName': False,
#   'isHideEmployerName': False,
#   'jobDetailsUrl': 'https://www.mycareersfuture.gov.sg/job/food-and-beverage/sales-director-argyll-scott-consulting-539df02ed701baaa6d20b5e8fb82b9cc'},
#  'salary': {'maximum': 15000,
#   'minimum': 12000,
#   'type': {'id': 4, 'salaryType': 'Monthly'}},
#  '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/jobs/539df02ed701baaa6d20b5e8fb82b9cc'},
#   'screeningQuestions': {'href': 'https://api.mycareersfuture.gov.sg/v2/jobs/539df02ed701baaa6d20b5e8fb82b9cc/screening-questions'}}}

# %%
def extract_mcf_data(json):
    
    output = {}
    transfer = ['uuid', 'title', 'description', 'minimumYearsExperience', 'numberOfVacancies']
    for key in transfer:
        output[key] = json[key]

    # Extract skills
    output['skills'] = ', '.join([entry['skill'] for entry in json['skills']])
    
    # Extract hiring company
    company = ['name', 'description', 'ssicCode', 'employeeCount']
    if json['metadata']['isPostedOnBehalf']:
        company_col = 'hiringCompany'
    else:
        company_col = 'postedCompany'
    for key in company:
        output['company_' + key] = json[company_col][key]
        
    # Extract metadata
    metadata = ['originalPostingDate', 'newPostingDate', 'expiryDate', 'totalNumberOfView', 'totalNumberJobApplication']
    for key in metadata:
        output[key] = json['metadata'][key]

    
    # Extract salary
    salary = ['maximum', 'minimum']
    for key in salary:
        output['salary_' + key] = json['salary'][key]
    
    return output

# %%
mcf_data = df_preds.merge(pd.DataFrame([extract_mcf_data(entry) for entry in final]), how = 'left', on = 'uuid')

# %%
mcf_final = mcf_data[mcf_data['title'].notnull()].drop_duplicates('description')

# %%
mcf_final.to_csv('Data/Processed/MCF_Training_Set_Full.csv', index = False)

# %%
mcf_final.shape
# Out:
# (42844, 19)

# %%
import os
os.chdir('C:\\Users\\shaun\\PycharmProjects\\ssoc-autocoder')
import pandas as pd

# %%
mcf_final = pd.read_csv('Data/Processed/MCF_Training_Set_Full.csv', low_memory = False)
output_df = mcf_final[['description', 'Predicted_SSOC_2020']]
output_df.columns = ['Description', 'SSOC 2020']

# %%
mcf_final
# Out:
#           MCF_Job_Ad_ID Predicted_SSOC_2020                              uuid  \
# 0      MCF-2020-0004327               11202  539df02ed701baaa6d20b5e8fb82b9cc
# 1      MCF-2020-0005420               21499  025e20c4553746731c77858dde113dcb
# 2      MCF-2020-0033506               14201  65d172acd8ba990726a1c725aa554008
# 3      MCF-2020-0063729               22692  62333158febf9ab5660c7c3f0cb45d12
# 4      MCF-2020-0073711               41109  e4863be8c042dbb8eda4af601b7338bf
# ...                 ...                 ...                               ...
# 42839  MCF-2021-0247058               41109  808271179f2b41f200ed9bd549db79bb
# 42840  MCF-2021-0247063               21499  6c33746d5f4434ccfee82df9d0b4cde9
# 42841  MCF-2021-0247083               21441  c76e644a0c5cd0e6ee978b632d48f773
# 42842  MCF-2021-0247098               26541  47456be3179841f60c7dfd33038f1579
# 42843  MCF-2021-0247102               83441  f5b8b70fc72fbfb2ae88f80f2d3cbddd
#
#                                                    title  \
# 0                                         Sales director
# 1                                 E&I INSPECTOR (COMPEX)
# 2                                          STORE MANAGER
# 3                         Associate Chiropractor Wanted!
# 4                                                  Admin
# ...                                                  ...
# 42839  Talent Acquisition Associate, Group HR, 6 Mont...
# 42840  #SGUnitedJobs Senior Research Engineer (Proces...
# 42841           Senior Cold chain system Design Engineer
# 42842              Video Production Editor #SGUnitedJobs
# 42843  Warehouse Assistant [Forklift / 5.5 Days / Tua...
#
#                                              description  \
# 0      <h3>Responsibilities:</h3>\n<h3>· Lead the man...
# 1      <h3>· Involved in Inspection and Commissioning...
# 2      <p><a href="https://www.snagajob.com/job-searc...
# 3      <h3><strong>WE ARE LOOKING FOR:</strong>​</h3>...
# 4      <p>1) Creating &amp; maintaining filing system...
# ...                                                  ...
# 42839  <p><strong>Roles &amp;   Responsibilities</str...
# 42840  <p>A qualified candidate will be self-motivate...
# 42841  <p><strong>Purpose of the position</strong><br...
# 42842  <h1>What we're looking for</h1>\n<p>Economics ...
# 42843  <p><strong>Job Description &amp; Requirements:...
#
#        minimumYearsExperience  numberOfVacancies  \
# 0                          10                  1
# 1                           5                  5
# 2                           5                  5
# 3                           1                  2
# 4                           1                  1
# ...                       ...                ...
# 42839                       0                  1
# 42840                       3                  1
# 42841                      10                  1
# 42842                       5                  1
# 42843                       1                  2
#
#                                                   skills  \
# 0      Account Management, Strategic Planning, Sales,...
# 1      Document Management, Operation, Engineering Ma...
# 2      Retail, Plan, Sales, Search, Schedule, Visual ...
# 3      Communication, Health Education, Holistic Heal...
# 4      Microsoft Office, Microsoft Excel, maintaining...
# ...                                                  ...
# 42839  Communication, Onboarding, telecommunation, Ta...
# 42840  Cleaning, Plan, autonomous, Development, Analy...
# 42841  project specification, Plan, Product Design, d...
# 42842  Editorial, designed, Documentaries, Adobe Prem...
# 42843  Multi Tasking, Job Descriptions, Able to Multi...
#
#                                   company_name  \
# 0            ARGYLL SCOTT CONSULTING PTE. LTD.
# 1      LISOON INDUSTRIAL ENGINEERING PTE. LTD.
# 2               SKY CAPITAL HOLDINGS PTE. LTD.
# 3        ORGANIC FAMILY CHIROPRACTIC PTE. LTD.
# 4               BINJAI INTERIOR DESIGN PTE LTD
# ...                                        ...
# 42839     SINGAPORE TELECOMMUNICATIONS LIMITED
# 42840                 A*STAR RESEARCH ENTITIES
# 42841                  LUCKLAND ASIA PTE. LTD.
# 42842         ECONOMICS DESIGN PRIVATE LIMITED
# 42843        THE SUPREME HR ADVISORY PTE. LTD.
#
#                                      company_description  company_ssicCode  \
# 0                                                    NaN           70201.0
# 1      <p>LISOON INDUSTRIAL ENGINEERING PTE. LTD.</p>...           30110.0
# 2                                                    NaN           10750.0
# 3       <p>ORGANIC FAMILY CHIROPRACTIC PTE. LTD.</p>\r\n           86909.0
# 4        <p>\r\n\tBINJAI INTERIOR DESIGN PTE LTD</p>\r\n           31001.0
# ...                                                  ...               ...
# 42839  <p>The SingTel Group is Asia's leading communi...           61099.0
# 42840                                                NaN           72104.0
# 42841                                                NaN           74191.0
# 42842  <p>Economics design focuses on the design of e...           62021.0
# 42843  <p>THE SUPREME HR ADVISORY PTE. LTD.</p>\r\n\r...           78104.0
#
#        company_employeeCount originalPostingDate newPostingDate  expiryDate  \
# 0                        NaN          2020-01-07     2020-01-07  2020-01-21
# 1                        NaN          2020-01-08     2020-01-08  2020-02-07
# 2                        NaN          2020-02-11     2020-02-11  2020-03-12
# 3                        NaN          2020-03-15     2020-07-21  2020-08-20
# 4                        NaN          2020-03-30     2020-07-06  2020-08-05
# ...                      ...                 ...            ...         ...
# 42839                    NaN          2021-05-31     2021-07-15  2021-08-14
# 42840                    NaN          2021-05-31     2021-05-31  2021-06-30
# 42841                    NaN          2021-05-31     2021-05-31  2021-06-30
# 42842                    NaN          2021-05-31     2021-05-31  2021-06-30
# 42843                    NaN          2021-05-31     2021-05-31  2021-06-30
#
#        totalNumberOfView  totalNumberJobApplication  salary_maximum  \
# 0                     53                          0           15000
# 1                     86                          0            3200
# 2                     78                          0            6000
# 3                    196                          0            6000
# 4                    471                          0            2400
# ...                  ...                        ...             ...
# 42839               1219                        124            3500
# 42840                114                          2           10200
# 42841                 96                          2            8500
# 42842                 31                          0            2000
# 42843                 21                          0            2000
#
#        salary_minimum
# 0               12000
# 1                2500
# 2                4000
# 3                4000
# 4                1800
# ...               ...
# 42839            2200
# 42840            5900
# 42841            7500
# 42842            1800
# 42843            1700
#
# [42844 rows x 19 columns]

# %%
data = mcf_final[~mcf_final['Predicted_SSOC_2020'].fillna('X').str.contains('X')].reset_index(drop = True)
data.to_csv('Data/Processed/MCF_Training_Set_Full.csv', index = False)

# %%
import hashlib
import requests

# %%
job_id = data.loc[22952]['MCF_Job_Ad_ID']
job_id_hash = hashlib.md5(job_id.encode()).hexdigest()
base_url = 'https://api.mycareersfuture.gov.sg/v2/jobs'
req = requests.get(base_url + "/" + job_id_hash)
print(req.json()['title'])
print(req.json()['ssocCode'])
print(req.json()['description'])
# Out:
# Head of Revenue
# 14752
# <p><strong>ABOUT US</strong></p>
# <p>RedDoorz is a Singapore-based travel tech company with offices in Indonesia, Philippines, Vietnam, India and Singapore. Our team have a diverse background - over 7 nationalities and previous work experiences from top companies such as Grab, Apple, Intercontinental, Lazada and Tata.</p>
# <p>We are <strong>transforming the hotel industry</strong> through the latest innovation in hospitality after the initial waves of Online Travel Agents and Airbnb. <strong>Unlike traditional hotel chains like Holiday Inn or Marriott</strong>, we don't build physical hotels but partner with hundreds of owners across 50+ cities, therefore being asset light and scalable. <strong>Unlike Online Travel Agents like Booking.com or Expedia</strong>, all our hotels under us are branded as RedDoorz - therefore we can drive quality and predictable stays to our customers. </p>
# <p><strong>Like Uber or Grab</strong>, we are the technology behind our hotel partners where we handle marketing, product development, customer service and data analytics under our brand. Like how Uber changes the transportation system, we are taking the same approach to the hotel industry. This <strong>asset light approach</strong> is the next big thing – it has attracted <strong>billions of funding</strong> from the likes of Softbank, Sequoia etc. </p>
# <p><strong>RESPONSIBILITIES</strong> </p>
# <p>As the Head of Revenue, you are challenged to lead the revenue teams across the geographies and establish revenue maximization efforts for all revenue streams of the group. Your responsibilities includes, but not limited to:- </p>
# <ul>
#   <li>Using predictive and prescriptive analytics to forecast demand and design appropriate revenue models.</li>
#   <li>Maintaining of Revenue Management standards; specific review and measurement of company revenue performance against established goals.</li>
#   <li>Overall development and implementation of strategy to improve revenue per acquired room for the properties across countries.</li>
#   <li>Monitoring group and transient business thresholds within the forecast to ensure measurable improvements for demand and availability.</li>
#   <li>Working with different departments like marketing, corporate sales and business development and control the impact that they create on revenue by setting individual targets for them</li>
#   <li>Working with external partners such OTAs &amp; other tech providers to ensure the best interest of the company.</li>
# </ul>
# <p><strong>REQUIREMENTS</strong></p>
# <ul>
#   <li>7+ years in diversified leadership roles, driving and implementing revenue growth</li>
#   <li>Min. Degree in Business Management or relevant preferred</li>
#   <li>Proficient with customer and operation analytics with grasp of business practices to implement the solutions.</li>
#   <li>Deep understanding of revenue functions with experience in the technology industry.</li>
#   <li>Deep understanding of customer acquisition, retention, user base based pricing techniques.</li>
#   <li>Sound negotiation skills with both internal and external parties.</li>
#   <li>Excellent organizational and interpersonal skills</li>
#   <li>Excellent leadership, management and problem solving skills with attention to detail and multitasking abilities.</li>
# </ul>

# %%
req.json()
# Out:
# {'uuid': '1b48cc9e49767b07bc2a60e96ca332bf',
#  'sourceCode': 'Employer Portal',
#  'title': 'On Site Coordinator ',
#  'description': '<p><strong>Responsibilities:</strong></p>\n<ul>\n  <li>Manage and control all ingress/egress in the Defined Area.</li>\n  <li>Daily updating of track access/book-ins and book-outs</li>\n  <li>Implement Workplace Safety and regulate the conduct of Works Train Station Supervisor.</li>\n  <li>Ensure routes are set and secured before authorising consist of movements.</li>\n  <li>Other duties as assigned.</li>\n</ul>\n<p><strong>Requirements:</strong></p>\n<ul>\n  <li>Local Diploma in Engineering Discipline</li>\n  <li>Min 5 years relevant past working experiences</li>\n  <li>Possess a relevant Class 3 or 4 local driving licence.</li>\n  <li>Knowledge of Microsoft Office application and able to provide weekly reports to the Work Train Manager.</li>\n  <li>To work independently and perform overtime work on a regular basis.</li>\n  <li>To conduct safety briefings related to Works Train operation</li>\n  <li>To handle situations, incidents, accidents and implement recovery measures in a calm and systematic manner.</li>\n  <li>Able to lead and take charge of a team of work groups.</li>\n</ul>',
#  'minimumYearsExperience': 5,
#  'shiftPattern': None,
#  'schemes': [],
#  'otherRequirements': None,
#  'ssocCode': 12675,
#  'workingHours': None,
#  'numberOfVacancies': 1,
#  'psdUrl': None,
#  'categories': [{'id': 11, 'category': 'Engineering'}],
#  'employmentTypes': [{'id': 8, 'employmentType': 'Full Time'}],
#  'positionLevels': [{'id': 8, 'position': 'Senior Executive'}],
#  'status': {'id': 9, 'jobStatus': 'Closed'},
#  'skills': [{'id': 1645,
#    'skill': 'Community Outreach',
#    'uuid': '0f51438947e37b6746984598f75be74a',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/0f51438947e37b6746984598f75be74a'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/0f51438947e37b6746984598f75be74a/jobs'}}},
#   {'id': 5644,
#    'skill': 'Microsoft Works',
#    'uuid': '1ea23477722a17b149bae14f210f6b55',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/1ea23477722a17b149bae14f210f6b55'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/1ea23477722a17b149bae14f210f6b55/jobs'}}},
#   {'id': 5628,
#    'skill': 'Microsoft Office',
#    'uuid': '2482944e6048d8f3b76417f0f5af9074',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/2482944e6048d8f3b76417f0f5af9074'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/2482944e6048d8f3b76417f0f5af9074/jobs'}}},
#   {'id': 6279,
#    'skill': 'Operation',
#    'uuid': '2a78ed76450c3cb42320882b3e055b31',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/2a78ed76450c3cb42320882b3e055b31'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/2a78ed76450c3cb42320882b3e055b31/jobs'}}},
#   {'id': 8957,
#    'skill': 'Teaching',
#    'uuid': '386533b1dd6d0732cfad59e8f631e35a',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/386533b1dd6d0732cfad59e8f631e35a'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/386533b1dd6d0732cfad59e8f631e35a/jobs'}}},
#   {'id': 3636,
#    'skill': 'Fundraising',
#    'uuid': '4c8c75203138b00ade0992311dca43c4',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/4c8c75203138b00ade0992311dca43c4'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/4c8c75203138b00ade0992311dca43c4/jobs'}}},
#   {'id': 100402,
#    'skill': 'Microsoft Acces',
#    'uuid': '5ef80ec102a9f8a91b397471f3be7bb5',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/5ef80ec102a9f8a91b397471f3be7bb5'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/5ef80ec102a9f8a91b397471f3be7bb5/jobs'}}},
#   {'id': 6102,
#    'skill': 'Nonprofits',
#    'uuid': '65b72587bc30b17e4cb29d9a0c9771d3',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/65b72587bc30b17e4cb29d9a0c9771d3'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/65b72587bc30b17e4cb29d9a0c9771d3/jobs'}}},
#   {'id': 100488,
#    'skill': 'work independently',
#    'uuid': '705d569f9582c71f7bc2bd1a0257acd9',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/705d569f9582c71f7bc2bd1a0257acd9'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/705d569f9582c71f7bc2bd1a0257acd9/jobs'}}},
#   {'id': 2655,
#    'skill': 'Driving',
#    'uuid': '8060dc318b0fafb0fc2e609eb5954723',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/8060dc318b0fafb0fc2e609eb5954723'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/8060dc318b0fafb0fc2e609eb5954723/jobs'}}},
#   {'id': 7263,
#    'skill': 'Public Speaking',
#    'uuid': '88aed6f147c2a31687cab0ff9d89b1e8',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/88aed6f147c2a31687cab0ff9d89b1e8'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/88aed6f147c2a31687cab0ff9d89b1e8/jobs'}}},
#   {'id': 3122,
#    'skill': 'Event Planning',
#    'uuid': '96aced0b7d642ea8c08c5ce8ec6262a1',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/96aced0b7d642ea8c08c5ce8ec6262a1'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/96aced0b7d642ea8c08c5ce8ec6262a1/jobs'}}},
#   {'id': 100029,
#    'skill': 'Control',
#    'uuid': 'a1595abbb4c3a326636dd178757cd6c1',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/a1595abbb4c3a326636dd178757cd6c1'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/a1595abbb4c3a326636dd178757cd6c1/jobs'}}},
#   {'id': 7576,
#    'skill': 'Research',
#    'uuid': 'f027f27d0d548351e4d362e9b90678a9',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/f027f27d0d548351e4d362e9b90678a9'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/f027f27d0d548351e4d362e9b90678a9/jobs'}}}],
#  'ssecEqa': '62',
#  'ssecFos': '1121',
#  'postedCompany': {'uen': '200723351G',
#   'description': '<p>GREENSAFE INTERNATIONAL PTE. LTD.</p>\r\n',
#   'name': 'GREENSAFE INTERNATIONAL PTE. LTD.',
#   'ssicCode': '70201',
#   'registrationTypeId': 1,
#   'employeeCount': None,
#   'companyUrl': None,
#   'lastSyncDate': '2021-10-11T01:02:36.000Z',
#   'badges': [{'badgeType': 'Tripartite',
#     'badgeCode': '004',
#     'badgeName': 'Tripartite Standard on Recruitment Practices',
#     'description': 'Adopting fair merit-based and inclusive hiring practices to better attract and retain talent.',
#     'url': 'https://www.tafep.sg/recruitment-practices',
#     'source': 'Tafep',
#     'startDate': '2021-10-10',
#     'expiryDate': '2022-10-10'}],
#   '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/companies/200723351G'},
#    'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/companies/200723351G/jobs'},
#    'addresses': {'href': 'https://api.mycareersfuture.gov.sg/v2/companies/200723351G/addresses'},
#    'schemes': {'href': 'https://api.mycareersfuture.gov.sg/v2/companies/200723351G/schemes'}},
#   'logoFileName': None,
#   'logoUploadPath': None},
#  'hiringCompany': None,
#  'screeningQuestions': [],
#  'address': {'overseasCountry': None,
#   'foreignAddress1': None,
#   'foreignAddress2': None,
#   'block': None,
#   'street': None,
#   'floor': None,
#   'unit': None,
#   'building': None,
#   'postalCode': None,
#   'isOverseas': False,
#   'districts': [{'id': 998,
#     'location': 'Islandwide',
#     'region': 'Islandwide',
#     'sectors': [],
#     'regionId': 'Islandwide'}]},
#  'metadata': {'jobPostId': 'MCF-2021-0212529',
#   'deletedAt': '2021-06-10T17:15:07.000Z',
#   'createdBy': 'a3db8100-1759-4030-8f11-73b8210c2bac',
#   'createdAt': '2021-05-11T03:54:01.000Z',
#   'updatedAt': '2021-06-10T16:36:20.000Z',
#   'editCount': 0,
#   'repostCount': 0,
#   'totalNumberOfView': 82,
#   'newPostingDate': '2021-05-11',
#   'originalPostingDate': '2021-05-11',
#   'expiryDate': '2021-06-10',
#   'totalNumberJobApplication': 6,
#   'isPostedOnBehalf': False,
#   'isHideSalary': False,
#   'isHideCompanyAddress': False,
#   'isHideHiringEmployerName': False,
#   'isHideEmployerName': False,
#   'jobDetailsUrl': 'https://www.mycareersfuture.gov.sg/job/engineering/site-coordinator-greensafe-international-1b48cc9e49767b07bc2a60e96ca332bf'},
#  'salary': {'maximum': 4500,
#   'minimum': 3000,
#   'type': {'id': 4, 'salaryType': 'Monthly'}},
#  '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/jobs/1b48cc9e49767b07bc2a60e96ca332bf'},
#   'screeningQuestions': {'href': 'https://api.mycareersfuture.gov.sg/v2/jobs/1b48cc9e49767b07bc2a60e96ca332bf/screening-questions'}}}

# %%
req.json()
# Out:
# {'uuid': '434ddd4eb00de81a9b6dabd968f36078',
#  'sourceCode': 'Employer Portal',
#  'title': 'Senior Staff Module Development Engineer ',
#  'description': '<p>Maxeon is seeking a world-class <strong>Senior Staff Module Development Engineer </strong>based in Singapore. It is expected that most of this work will be carried out at a new state-of-the-art Maxeon RD&amp;D Laboratory to be created in Singapore. Job responsibilities include research and development of new solar technology that pushes the limit of efficiency at lower cost, working closely with Maxeon’s renowned US based R&amp;D team, and supporting existing teams in deploying and optimizing solar technology at Maxeon’s factories. This work is expected to include both cell and module technology development for Maxeon’s advanced product portfolio. The goal of these activities is to support Maxeon’s business objectives, including market expansion, with targeted advanced technology.</p>\n<p><strong>ESSENTIAL DUTIES AND RESPONSIBILITIES</strong></p>\n<ul>\n  <li>Work closely with Fab/Modco teams to develop and help deploy advanced high efficiency state of the art module products using next generation manufacturing technologies.</li>\n  <li>Help select the initial equipment and tools for the Singapore Lab.</li>\n  <li>Deliver significant innovation that enhances Maxeon’s performance advantage, while reducing manufacturing cost and capital cost.</li>\n  <li>Innovate relentlessly on new module designs to reduce cost, improve manufacturability, and enhance reliability or meet new market segment needs.</li>\n  <li>Ensure that your project milestones and deliverables are met, delivered on time, and adhere to approved budgets.</li>\n  <li>Work closely with Maxeon organizations outside of the Singapore location.</li>\n  <li>Help develop company technology and product goals, plan technology projects and deliver these goals using the Maxeon business processes.</li>\n  <li>Provide excellent communication within Maxeon to facilitate tracking and coordinating technology and product development goals and milestones.</li>\n</ul>\n<p><strong>RELATED EXPERIENCE AND EDUCATIONAL REQUIREMENTS</strong></p>\n<p><strong>Minimum Qualifications:</strong></p>\n<ul>\n  <li>PhD Degree with at least 4 years additional relevant R&amp;D experience or &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;equivalent.</li>\n  <li>Proven track record of highly significant advanced Solar PV innovation.</li>\n  <li>Strong process and characterization skills in solar modules or other high volume manufacturing products.</li>\n  <li>Demonstrated ability to lead complex interdisciplinary projects using industry standard planning tools such as Microsoft Project to achieve goals on time and on budget.</li>\n  <li>Excellent written and verbal communication skills.</li>\n  <li>Willing to travel in Asia and US up to 25% of the time.</li>\n</ul>\n<p><strong>Preferred requirements</strong></p>\n<ul>\n  <li>Expert knowledge of PV module product landscape and high value add market opportunities.</li>\n  <li>Proven record of working very effectively with multiple organizations both within a company and outside the company.</li>\n  <li>PV technology R&amp;D breadth encompassing module technology at an advanced level.</li>\n  <li>Detailed understanding of PV module downstream requirements from installers and project developers.</li>\n  <li>Good understanding of failure analysis principles.</li>\n  <li>Good programing and modelling experience (e.g. Python, C++, JMP, R, etc).</li>\n  <li>Familiarity with solar cell factory production and solar panel manufacturing.</li>\n  <li>Substantial knowledge of PV cell and module reliability, including modeling and testing.</li>\n  <li>Good understanding of people and project management principles.</li>\n  <li>Knowledge of laboratory and equipment safety standards.</li>\n</ul>',
#  'minimumYearsExperience': 4,
#  'shiftPattern': None,
#  'schemes': [],
#  'otherRequirements': None,
#  'ssocCode': 10655,
#  'workingHours': None,
#  'numberOfVacancies': 1,
#  'psdUrl': None,
#  'categories': [{'id': 36, 'category': 'Sciences / Laboratory / R&D'}],
#  'employmentTypes': [{'id': 7, 'employmentType': 'Permanent'}],
#  'positionLevels': [{'id': 8, 'position': 'Senior Executive'}],
#  'status': {'id': 9, 'jobStatus': 'Closed'},
#  'skills': [{'id': 5640,
#    'skill': 'Microsoft Technologies',
#    'uuid': '08b032b281f8fe960ef34b2b34977cd2',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/08b032b281f8fe960ef34b2b34977cd2'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/08b032b281f8fe960ef34b2b34977cd2/jobs'}}},
#   {'id': 100035,
#    'skill': 'business objectives',
#    'uuid': '0ad1446f77f8251f4f26b9bbba44558f',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/0ad1446f77f8251f4f26b9bbba44558f'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/0ad1446f77f8251f4f26b9bbba44558f/jobs'}}},
#   {'id': 7357,
#    'skill': 'R&D',
#    'uuid': '2f99609fe3ff2cd1f17d6ea9945ea9f6',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/2f99609fe3ff2cd1f17d6ea9945ea9f6'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/2f99609fe3ff2cd1f17d6ea9945ea9f6/jobs'}}},
#   {'id': 105411,
#    'skill': 'solar technology',
#    'uuid': '32c3e44d39b38a891c4ac4da0be7797b',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/32c3e44d39b38a891c4ac4da0be7797b'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/32c3e44d39b38a891c4ac4da0be7797b/jobs'}}},
#   {'id': 2412,
#    'skill': 'Development',
#    'uuid': '330f49df8243756a8a4dc7f7f7ee6dfe',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/330f49df8243756a8a4dc7f7f7ee6dfe'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/330f49df8243756a8a4dc7f7f7ee6dfe/jobs'}}},
#   {'id': 100165,
#    'skill': 'efficient',
#    'uuid': '54f7b01b04b120ae34714e0b6b8a0045',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/54f7b01b04b120ae34714e0b6b8a0045'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/54f7b01b04b120ae34714e0b6b8a0045/jobs'}}},
#   {'id': 4801,
#    'skill': 'JavaScript',
#    'uuid': '686155af75a60a0f6e9d80c1f7edd3e9',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/686155af75a60a0f6e9d80c1f7edd3e9'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/686155af75a60a0f6e9d80c1f7edd3e9/jobs'}}},
#   {'id': 8383,
#    'skill': 'Solar Energy',
#    'uuid': '74d776d59d7232a3df2ed82a3a1ea8d9',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/74d776d59d7232a3df2ed82a3a1ea8d9'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/74d776d59d7232a3df2ed82a3a1ea8d9/jobs'}}},
#   {'id': 7086,
#    'skill': 'Production',
#    'uuid': '756d97bb256b8580d4d71ee0c547804e',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/756d97bb256b8580d4d71ee0c547804e'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/756d97bb256b8580d4d71ee0c547804e/jobs'}}},
#   {'id': 7578,
#    'skill': 'Research and Development',
#    'uuid': '82be779191266b6ef0597be0c7f60d6d',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/82be779191266b6ef0597be0c7f60d6d'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/82be779191266b6ef0597be0c7f60d6d/jobs'}}},
#   {'id': 2953,
#    'skill': 'Engineering',
#    'uuid': 'ab0268fb8036a892dc341945cb7ae3be',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/ab0268fb8036a892dc341945cb7ae3be'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/ab0268fb8036a892dc341945cb7ae3be/jobs'}}},
#   {'id': 7146,
#    'skill': 'Project Development',
#    'uuid': 'ae39271eb47e5624f024adc7807dce0d',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/ae39271eb47e5624f024adc7807dce0d'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/ae39271eb47e5624f024adc7807dce0d/jobs'}}},
#   {'id': 100532,
#    'skill': 'product portfolio',
#    'uuid': 'b5b3c8beaff3644a1224cb13fd9ad3ef',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/b5b3c8beaff3644a1224cb13fd9ad3ef'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/b5b3c8beaff3644a1224cb13fd9ad3ef/jobs'}}},
#   {'id': 7064,
#    'skill': 'Product Development',
#    'uuid': 'd324e27fb1cf5931e17c08a9a85f76bf',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/d324e27fb1cf5931e17c08a9a85f76bf'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/d324e27fb1cf5931e17c08a9a85f76bf/jobs'}}},
#   {'id': 4794,
#    'skill': 'Java',
#    'uuid': 'd52387880e1ea22817a72d3759213819',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/d52387880e1ea22817a72d3759213819'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/d52387880e1ea22817a72d3759213819/jobs'}}},
#   {'id': 5347,
#    'skill': 'Manufacturing',
#    'uuid': 'e86883c7cfc07afcf1e5ad8dffd7e1cc',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/e86883c7cfc07afcf1e5ad8dffd7e1cc'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/e86883c7cfc07afcf1e5ad8dffd7e1cc/jobs'}}},
#   {'id': 8355,
#    'skill': 'Software Development',
#    'uuid': 'f287f429e4026672e5754c1201691e49',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/f287f429e4026672e5754c1201691e49'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/f287f429e4026672e5754c1201691e49/jobs'}}},
#   {'id': 9099,
#    'skill': 'Testing',
#    'uuid': 'fa6a5a3224d7da66d9e0bdec25f62cf0',
#    'confidence': None,
#    '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/fa6a5a3224d7da66d9e0bdec25f62cf0'},
#     'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/fa6a5a3224d7da66d9e0bdec25f62cf0/jobs'}}}],
#  'ssecEqa': '92',
#  'ssecFos': '1299',
#  'postedCompany': {'uen': '201427011M',
#   'description': None,
#   'name': 'SUNPOWER ENERGY SYSTEMS SINGAPORE PTE. LTD.',
#   'ssicCode': '70201',
#   'registrationTypeId': 0,
#   'employeeCount': None,
#   'companyUrl': None,
#   'lastSyncDate': '2021-10-06T00:28:18.000Z',
#   'badges': [],
#   '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/companies/201427011M'},
#    'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/companies/201427011M/jobs'},
#    'addresses': {'href': 'https://api.mycareersfuture.gov.sg/v2/companies/201427011M/addresses'},
#    'schemes': {'href': 'https://api.mycareersfuture.gov.sg/v2/companies/201427011M/schemes'}},
#   'logoFileName': None,
#   'logoUploadPath': None},
#  'hiringCompany': None,
#  'screeningQuestions': [],
#  'address': {'overseasCountry': None,
#   'foreignAddress1': None,
#   'foreignAddress2': None,
#   'block': '8',
#   'street': 'MARINA BOULEVARD',
#   'floor': None,
#   'unit': None,
#   'building': 'MARINA BAY FINANCIAL CENTRE',
#   'postalCode': '018981',
#   'isOverseas': False,
#   'districts': [{'id': 1,
#     'location': 'D01 Cecil, Marina, People’s Park, Raffles Place',
#     'region': 'Central',
#     'sectors': ['01', '02', '03', '04', '05', '06'],
#     'regionId': 'Central'}],
#   'lat': 1.27946811236052,
#   'lng': 103.85374955357},
#  'metadata': {'jobPostId': 'MCF-2021-0040703',
#   'deletedAt': '2021-02-27T17:15:13.000Z',
#   'createdBy': '79fc66e1-3bb7-46a5-b897-56590780ba3e',
#   'createdAt': '2021-01-28T03:42:29.000Z',
#   'updatedAt': '2021-02-27T17:15:14.000Z',
#   'editCount': 0,
#   'repostCount': 0,
#   'totalNumberOfView': 161,
#   'newPostingDate': '2021-01-28',
#   'originalPostingDate': '2021-01-28',
#   'expiryDate': '2021-02-27',
#   'totalNumberJobApplication': 4,
#   'isPostedOnBehalf': False,
#   'isHideSalary': False,
#   'isHideCompanyAddress': False,
#   'isHideHiringEmployerName': False,
#   'isHideEmployerName': False,
#   'jobDetailsUrl': 'https://www.mycareersfuture.gov.sg/job/sciences/senior-staff-module-development-engineer-sunpower-energy-systems-singapore-434ddd4eb00de81a9b6dabd968f36078'},
#  'salary': {'maximum': 15000,
#   'minimum': 8000,
#   'type': {'id': 4, 'salaryType': 'Monthly'}},
#  '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/jobs/434ddd4eb00de81a9b6dabd968f36078'},
#   'screeningQuestions': {'href': 'https://api.mycareersfuture.gov.sg/v2/jobs/434ddd4eb00de81a9b6dabd968f36078/screening-questions'}}}

# %%
from ssoc_autocoder import processing

# %%
cleaned = []
for i, desc in enumerate(output_df['Description']):
    if (i+1) % 100 == 0:
        print(f'Processing {i+1}/{len(output_df)}...\r', end = '')
    try:
        cleaned_desc = processing.process_text(desc)
    except KeyboardInterrupt:
        break 
    except:
        print(f'Error found in index {i}...')
        cleaned_desc = processing.final_cleaning(desc)
    cleaned.append(cleaned_desc)
# Out:
# Error found in index 3071...
# Error found in index 3688...
# Error found in index 7005...
# Error found in index 18283...
# Error found in index 19336...
# Error found in index 25188...
# Error found in index 27221...
# Error found in index 34863...
# Error found in index 38110...
# Error found in index 40663...
# Error found in index 41018...
# Processing 42800/42844...

# %%
output_df['Cleaned_Description'] = cleaned
# Out:
# C:\Users\shaun\AppData\Local\Temp/ipykernel_9464/3941138137.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df['Cleaned_Description'] = cleaned

# %%
output_df.to_csv('Data/Processed/training/train_full.csv', index = False)

# %%
processing.final_cleaning(output_df['Description'][41018])
# Out:
# "1 Data entry duties and administrative duties include: Preparing quotation, final bill of quantity and sales invoices for the project you are assigned to. 2 Support project manager/ M&E coordinator. 3 Handling emails related to the project. 4 Ability to be on time and complete task in an efficient manner. 5 Manage databases and admin systems. 6 Organizing, storing paperwork, documents and computer-based documents. 7 Assisting in other office ad-ho duties when required. Skills Requirements. 1 Neat administrative and good organisational skills. 2 Able to thrive and work individually and independently. 3 Experienced and proficient in Excel. 4 Communication in English. 5 Possess ability to work on own initiative. 6 Fast learner. 7 Candidate must possess at least N's Level and above. Other information. 1 5.5 working days (alternate Saturdays off) (Mon - Fri: 8:30am to 5:30pm, Sat: 8:30am to 1pm) . 2 Location is in Kaki Bukit. 3 Full time job. 4 Work life balance. Kindly state your expected salary & date of availability when submitting your application. Kindly note that only shortlisted candidates will be notified."

# %%
output_df['Description'][41018]
# Out:
# '<p>Responsibilities\t\t\t\t\t\t\t\t</p>\n<p>\t\t\t\t\t\t\t\t</p>\n<p>1\tData entry duties and administrative duties include: Preparing quotation, final bill of quantity and sales invoices for the project you are assigned to\t\t\t\t\t\t\t</p>\n<p>2\tSupport project manager/ M&amp;E coordinator\t\t\t\t\t\t\t</p>\n<p>3\tHandling emails related to the project\t\t\t\t\t\t\t</p>\n<p>4\tAbility to be on time and complete task in an efficient manner\t\t\t\t\t\t\t</p>\n<p>5\tManage databases and admin systems\t\t\t\t\t\t\t</p>\n<p>6\tOrganizing, storing paperwork, documents and computer-based documents\t\t\t\t\t\t\t</p>\n<p>7\tAssisting in other office ad-ho duties when required\t\t\t\t\t\t\t</p>\n<p>\t\t\t\t\t\t\t\t</p>\n<p>Skills Requirements\t\t\t\t\t\t\t\t</p>\n<p>\t\t\t\t\t\t\t\t</p>\n<p>1\tNeat administrative and good organisational skills\t\t\t\t\t\t\t</p>\n<p>2\tAble to thrive and work individually and independently\t\t\t\t\t\t\t</p>\n<p>3\tExperienced and proficient in Excel\t\t\t\t\t\t\t</p>\n<p>4\tCommunication in English\t\t\t\t\t\t\t</p>\n<p>5\tPossess ability to work on own initiative\t\t\t\t\t\t\t</p>\n<p>6\tFast learner\t\t\t\t\t\t\t</p>\n<p>7\tCandidate must possess at least N’s Level and above\t\t\t\t\t\t\t</p>\n<p>\t\t\t\t\t\t\t\t</p>\n<p>Other information\t\t\t\t\t\t\t\t</p>\n<p>1\t5.5 working days (alternate Saturdays off) (Mon - Fri: 8:30am to 5:30pm, Sat: 8:30am to 1pm)\t\t\t\t\t\t\t</p>\n<p>2\tLocation is in Kaki Bukit\t\t\t\t\t\t\t</p>\n<p>3\tFull time job\t\t\t\t\t\t\t</p>\n<p>4\tWork life balance\t\t\t\t\t\t\t</p>\n<p>\t\t\t\t\t\t\t</p>\n<p>\t\t\t\t\t\t\t\t</p>\n<p>Kindly state your expected salary &amp; date of availability when submitting your application.\t\t\t\t\t\t\t\t</p>\n<p>Kindly note that only shortlisted candidates will be notified.\t\t\t\t\t\t\t\t</p>\n<p><br></p>'
