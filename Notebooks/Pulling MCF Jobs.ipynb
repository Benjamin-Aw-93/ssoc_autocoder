# %%
import pandas as pd
import requests
import hashlib 
import time

# %%
mcf_ids_raw = {'Job Ad Id': ['MCF-2021-0334514', 'MCF-2021-0300571']}
mcf_ids = pd.DataFrame(mcf_ids_raw)

# %%
mcf_ids['uuid'] = [hashlib.md5(job_id.encode()).hexdigest() for job_id in mcf_ids['Job Ad Id']]

# %%
mcf_ids.head()
# Out:
#           Job Ad Id                              uuid
# 0  MCF-2021-0334514  20c875b6cfacd68fe3667f5ab6b15c5c
# 1  MCF-2021-0300571  dd4ceadcc7174a3be99bcebef566fbc9

# %%
base_url = 'https://api.mycareersfuture.gov.sg/v2/jobs'

output = []
for uuid in mcf_ids['uuid']:
    req = requests.get(base_url + "/" + uuid)
    if req.status_code == 200:
        output.append(req.json())
        time.sleep(.1)
    else:
        print('Backing off...')
        time.sleep(2)
        req = requests.get(base_url + "/" + uuid)
        output.append(req.json())

# %%
output[0]['skills']
# Out:
# [{'id': 6782,
#   'skill': 'PL/SQL',
#   'uuid': '1f93cbc3d076ca8436b48d4d75fb0939',
#   'confidence': None,
#   '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/1f93cbc3d076ca8436b48d4d75fb0939'},
#    'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/1f93cbc3d076ca8436b48d4d75fb0939/jobs'}}},
#  {'id': 100013,
#   'skill': 'designed',
#   'uuid': '3677b55b4fb1c656b2a6ec776093be88',
#   'confidence': None,
#   '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/3677b55b4fb1c656b2a6ec776093be88'},
#    'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/3677b55b4fb1c656b2a6ec776093be88/jobs'}}},
#  {'id': 4720,
#   'skill': 'Issue Management',
#   'uuid': '3fa25db427db361eee13817c6f4c7726',
#   'confidence': None,
#   '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/3fa25db427db361eee13817c6f4c7726'},
#    'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/3fa25db427db361eee13817c6f4c7726/jobs'}}},
#  {'id': 106862,
#   'skill': 'continuous service improvement',
#   'uuid': '5c363f7d14235f9b84fb8db37da0e848',
#   'confidence': None,
#   '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/5c363f7d14235f9b84fb8db37da0e848'},
#    'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/5c363f7d14235f9b84fb8db37da0e848/jobs'}}},
#  {'id': 103219,
#   'skill': 'Virtual Team Management',
#   'uuid': '5e787afb60231bf21851514bb59d3d80',
#   'confidence': None,
#   '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/5e787afb60231bf21851514bb59d3d80'},
#    'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/5e787afb60231bf21851514bb59d3d80/jobs'}}},
#  {'id': 100045,
#   'skill': 'proactive',
#   'uuid': '649fad33d5dfe9bc2db640f8d09bb099',
#   'confidence': None,
#   '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/649fad33d5dfe9bc2db640f8d09bb099'},
#    'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/649fad33d5dfe9bc2db640f8d09bb099/jobs'}}},
#  {'id': 7093,
#   'skill': 'Production Support',
#   'uuid': '97349fc54cbfa5fba536828de1af9ac2',
#   'confidence': None,
#   '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/97349fc54cbfa5fba536828de1af9ac2'},
#    'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/97349fc54cbfa5fba536828de1af9ac2/jobs'}}},
#  {'id': 8523,
#   'skill': 'SQL',
#   'uuid': '9778840a0100cb30c982876741b0b5a2',
#   'confidence': None,
#   '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/9778840a0100cb30c982876741b0b5a2'},
#    'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/9778840a0100cb30c982876741b0b5a2/jobs'}}},
#  {'id': 100716,
#   'skill': 'organisational',
#   'uuid': 'a115ee1cbc7a265ada840b885ed53cb8',
#   'confidence': None,
#   '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/a115ee1cbc7a265ada840b885ed53cb8'},
#    'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/a115ee1cbc7a265ada840b885ed53cb8/jobs'}}},
#  {'id': 400,
#   'skill': 'Application Support',
#   'uuid': 'a1ea28161497355d2e25cbef64a119b7',
#   'confidence': None,
#   '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/a1ea28161497355d2e25cbef64a119b7'},
#    'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/a1ea28161497355d2e25cbef64a119b7/jobs'}}},
#  {'id': 100189,
#   'skill': 'Lead and coach',
#   'uuid': 'bbd6f7dceaf4ebeefb69fb00fe6a4438',
#   'confidence': None,
#   '_links': {'self': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/bbd6f7dceaf4ebeefb69fb00fe6a4438'},
#    'jobs': {'href': 'https://api.mycareersfuture.gov.sg/v2/skills/bbd6f7dceaf4ebeefb69fb00fe6a4438/jobs'}}}]

# %%
def extract_mcf_data(json):
    
    output = {}
    transfer = ['uuid', 'title', 'description', 'minimumYearsExperience', 'numberOfVacancies']
    for key in transfer:
        output[key] = json[key]

    # Extract skills
    output['skills'] = ', '.join([entry['skill'] for entry in json['skills']])
    
    # Extract hiring company
    company = ['name', 'description', 'ssicCode', 'employeeCount']
    if json['metadata']['isPostedOnBehalf']:
        company_col = 'hiringCompany'
    else:
        company_col = 'postedCompany'
    for key in company:
        output['company_' + key] = json[company_col][key]
        
    # Extract metadata
    metadata = ['originalPostingDate', 'newPostingDate', 'expiryDate', 'totalNumberOfView', 'totalNumberJobApplication']
    for key in metadata:
        output[key] = json['metadata'][key]

    
    # Extract salary
    salary = ['maximum', 'minimum']
    for key in salary:
        output['salary_' + key] = json['salary'][key]
    
    return output

# %%
mcf_data = mcf_ids.merge(pd.DataFrame([extract_mcf_data(entry) for entry in output]), how = 'left', on = 'uuid')
mcf_final = mcf_data.drop_duplicates()

# %%
mcf_final.head()
# Out:
#           Job Ad Id                              uuid  \
# 0  MCF-2021-0334514  20c875b6cfacd68fe3667f5ab6b15c5c
# 1  MCF-2021-0300571  dd4ceadcc7174a3be99bcebef566fbc9
#
#                              title  \
# 0  Production Support Lead Analyst
# 1                     Unit Manager
#
#                                          description  minimumYearsExperience  \
# 0  <p><strong>Role   Description</strong></p>\n<p...                       5
# 1  <p><strong>Job Description</strong></p>\n<p><b...                      10
#
#    numberOfVacancies                                             skills  \
# 0                  1  PL/SQL, designed, Issue Management, continuous...
# 1                  1  Negotiation, Coaching, business understanding,...
#
#                          company_name  \
# 0  FNZ (SINGAPORE) SERVICES PTE. LTD.
# 1     SUZETTE INTERNATIONAL PTE. LTD.
#
#                                  company_description company_ssicCode  \
# 0                                                               66199
# 1  <p>Henri Charpentier, famous popular Japanese ...            47213
#
#    company_employeeCount originalPostingDate newPostingDate  expiryDate  \
# 0                    NaN          2021-07-13     2021-07-13  2021-08-12
# 1                   25.0          2021-06-25     2021-06-25  2021-07-25
#
#    totalNumberOfView  totalNumberJobApplication  salary_maximum  \
# 0                292                         20           10000
# 1                354                         39            9700
#
#    salary_minimum
# 0            7500
# 1            9400
