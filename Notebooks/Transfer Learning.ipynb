# %% [markdown]
# ## Applying Transfer Learning to the SSOC Autocoder
#
# Adapted from [here](https://github.com/abhimishra91/transformers-tutorials/blob/master/transformers_multiclass_classification.ipynb)

# %%
# Importing the libraries needed
import pandas as pd
import torch
import transformers
from torch.utils.data import Dataset, DataLoader
from transformers import DistilBertModel, DistilBertTokenizer

# %%
import pandas as pd

# %%
SSOC_Definitions = pd.read_excel('../Data/Raw/SSOC2020 Detailed Definitions.xlsx', skiprows = 4)
# Out:
# c:\users\shaun\pycharmprojects\ssoc-autocoder\venv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
SSOC_4D = SSOC_Definitions[SSOC_Definitions['SSOC 2020'].apply(len) == 4]

# %%
SSOC_4D
# Out:
#      SSOC 2020                                    SSOC 2020 Title  \
# 3         1111                                        Legislators
# 5         1112    Senior Government and Statutory Board Officials
# 8         1114  Senior Officials of Political Party Organisations
# 10        1115  Senior Officials of Employers', Workers' and O...
# 12        1116  Senior Officials of Humanitarian and Other Spe...
# ...        ...                                                ...
# 1580      9621                        Porters and Related Workers
# 1584      9625                                         Attendants
# 1593      9626                       Watchmen and Related Workers
# 1597      9627                      Concierge and Related Workers
# 1600      9629        Elementary Workers Not Elsewhere Classified
#
#                       Groups Classified Under this Code  \
# 3                                   •  11110 Legislator
# 5     •  11121 Senior government official\n•  11122 ...
# ...
